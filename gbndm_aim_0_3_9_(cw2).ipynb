# %% [markdown]
# <a href="https://colab.research.google.com/github/hcyws1/AI-coursework-2/blob/master/gbndm_aim_0_3_9_(cw2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optimizing neurally diverse architectures for small and imbalanced subsets of MNIST
#
# * This notebook is for exploring architectural specifications for neurally diverse architectures on a small and imbalanced version of MNIST.
# * The architecture includes pre-branch, branch, and post-branch segments. Neural diversity is implemented specifically at the level of activation function non-linearity and a small wet of "connection functions" (i.e. linear, identity, and element-wise scaling).
# * A highly simplistic form of architectural search based on stochastic hill-climbing with some differential search is included, for your reference.
# * 0.3.7 - added id and elementwise scaling weight functions.
# * 0.3.8 - added training acuracies; do_train is now returning the model with the best validation error.
# * 0.3.9 - added basic DropCircuit.

# %%
version = '_v0p3p9_'

import time
import warnings

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

import torch
import numpy as np
from torch.utils import data
import copy

from __future__ import print_function
import argparse
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

from IPython.core.debugger import set_trace

# ===============
# Initializations
# ===============

# !pip install torch torchvision

# ===============
# Parameters
# ===============

# --- General framework arguments

args = {}
kwargs = {}
args['num_train_batch'] = 1  # number of MNIST training batches
args['num_valid_batch'] = 10  # number of MNIST validation batches
args['train_batch_size'] = 100   # training batch size
args['valid_batch_size'] = 100   # validation batch size
args['test_batch_size'] = 10
# args['epochs'] = 100  # number of training epochs 
args['lr'] = 1 # 0.1  # 0.01 # learning rate # this is over-written by the solution
args['momentum'] = 0.5 # SGD momentum (default: 0.5); momentum is a moving average of our gradients (helps keep a useful direction)
args['clip_level'] = 0.5  # gradient clip threshold
args['seed']= 1 #random seed
args['log_interval_epoch'] = 1 # display training loss every log_int... epochs
args['cuda'] = True 
args['patience'] = 1000  # stop train. if the valid. err. hasn't improved by this num. of epochs
args['noise_in'] = -1   # 0.5  # 0.15  # amount of noise to add to the training data
args['noise_out'] = -1   #  probability of changing an output label to some random label
args['verbose_train'] = False   # print status of model training?
args['verbose_meta'] = True #  print status of architecture optimization?
args['min_inst_class'] = 5 # minimum number of instances per class in the training set
args['batch_max_tries'] = 10 # max. num. of attempts in extracting data batches
args['save_best_chrom'] = True # False  # save the best chromose in Google Drive?
args['dc_prob_drop'] = 0.5 # 0.5 # probability of dropping a circuit (DropCircuit)
args['prob_sel_branch'] = 0.5 # probability of architectural search selecting/using a branch (this is not DropCircuit) 

# --- Neural architectural limits

args['num_epochs_search'] = 10 # 100  # number of epochs for training during architecture search 
args['num_epochs_test'] = 1000  # num. epochs for training during the final test
limits = {}
limits['min_layer_nodes'] =  10 # 5 # 50
limits['max_layer_nodes'] = 100
limits['max_pre_branch_layers'] = 5 # 3
limits['max_branches'] = 10
limits['max_branch_layers'] = 5  # 3
limits['max_post_branch_layers'] = 5 # 3
limits['lr1_min'] = 0.001
limits['lr1_,max'] = 2
limits['lr2_min'] = 0.001
limits['lr2_,max'] = 2
limits['moment_min'] = 0.001
limits['moment_max'] = 1

# np.random.seed(0)
# torch.manual_seed(0)

num_train_instances = args['num_train_batch'] * args['train_batch_size']
num_valid_instances = args['num_valid_batch'] * args['valid_batch_size']

data_rand_seed = 1 # (other pre-tested seeds: 2, 3)

# ============
# Load dataset
# ============

# Seed creation
torch.manual_seed(data_rand_seed)
np.random.seed(data_rand_seed)

a_data_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
  
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=a_data_transform),
    batch_size=args['train_batch_size'], shuffle=True, **kwargs)

test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=a_data_transform),
    batch_size=args['test_batch_size'], shuffle=True, **kwargs)

# Check whether we have enough instances per class
# We want an imbalanced dataset but we don't want any specific label having
# an "insufficient" number of instances.
def check_enough_inst(batches, min_inst_per_class):
  
  # Concatenate training batch output labels
  labels = batches[0][1].numpy()
  for batch_i in range(1,args['num_train_batch']):
    new_labels = batches[batch_i][1].numpy()
    labels = np.concatenate((labels, new_labels))

  labels = labels.tolist()

  # Scan though labels
  for a_label in range(10):  # assuming MNIST, of course
    a_count = labels.count(a_label)
    # If label count is < min_inst_per_class return False
    if a_count < min_inst_per_class:
      return False

  # Return True
  return True


# Prepare data. Extract training and validation batches
# This is where we make the problem "small and imbalanced"
def extract_batches(a_loader, min_inst_per_class, max_tries):

  # Keep trying until you have a required minimum number of instances 
  # per class in the training set (not elegant but ok for the range of 
  # "min_inst_per_class" we need)

  for ti in range(max_tries):

    print('Data extraction trial {}.'.format(ti))

    # Initializations
    train_batches = []
    valid_batches = []
    tot_batch_extract = args['num_train_batch'] + args['num_valid_batch']

    # Extract
    for batch_idx, (data, target) in enumerate(a_loader):

      if batch_idx < args['num_train_batch']:
        train_batches.append((data,target))
      else:
        valid_batches.append((data,target))
        if batch_idx == tot_batch_extract - 1:
          break

    # Check minimum number of instances
    enough_instaces = check_enough_inst(train_batches, min_inst_per_class)
    if enough_instaces:
      return train_batches, valid_batches

  print('It was not possible to create a dataset.')
  print('Consider increasing the overall number of instances, or')
  print('decreasing the minimum instances per class allowed.')
  return [], []


train_batches, valid_batches = extract_batches(train_loader, args['min_inst_class'], args['batch_max_tries'])
if args['verbose_train']:
  print('Extracted {} train_batches, and {} valid_batches.'.format(len(train_batches), len(valid_batches)))

# ===========================
# Display histogram of labels
# ===========================

def disp_hist_labaels(batches):
  # Concatenate training batch output labels
  labels = batches[0][1].numpy()
  for batch_i in range(1,args['num_train_batch']):
    new_labels = batches[batch_i][1].numpy()
    labels = np.concatenate((labels, new_labels))

  num_bins = 10
  n, bins, patches = plt.hist(labels, num_bins, facecolor='blue', alpha=0.5)
  plt.show()

disp_hist_labaels(train_batches)

# ==========================
# Display dataset
# ==========================

# This is not currently used

# Display MNIST instances
# Adapted from # https://github.com/CSCfi/machine-learning-scripts/blob/master/notebooks/pytorch-mnist-mlp.ipynb
def disp_MNIST_inst(num_disp, X_train, y_train):
  pltsize=1
  plt.figure(figsize=(num_disp*pltsize, pltsize))
  for i in range(num_disp):
    plt.subplot(1,num_disp,i+1)
    plt.axis('off')
    plt.imshow(X_train[i,:,:].numpy().reshape(28,28), cmap="gray_r")
    plt.title('Class: '+str(y_train[i].item()))

if args['verbose_train']:
  X_train = train_batches[0][0]
  y_train = train_batches[0][1]

  disp_MNIST_inst(10, X_train, y_train)

  sum_train_0 = X_train[0,:,:].sum()
  min_train_0 = X_train[0,:,:].min()
  max_train_0 = X_train[0,:,:].max()

  print('X_train[0,:,:] --> sum ({}); min ({}); max ({}).'.format(sum_train_0, min_train_0, max_train_0))

# ==========================
# Design model
# ==========================

# "Unseed" the rest
np.random.seed()
a_rand_seed = np.random.randint(0,999999)
torch.manual_seed(a_rand_seed)

# Simple function to scale parameters
# num is assume to be \in [0,1]
def scale_to_range(num,min_val,max_val):
  range = max_val - min_val
  return (num*range)+min_val

# Simple layer for doing elementwise scaling
# Adapated from https://stackoverflow.com/questions/51980654/pytorch-element-wise-filter-layer
class Elem_Scaling_1D(nn.Module):
  def __init__(self, num_nodes, bogus):  # clean-up "bogus"
    super(Elem_Scaling_1D, self).__init__()
    # Initialize
    init_weights = np.random.normal(loc=0, scale=0.5, size=np.shape(num_nodes))
    # Assign
    self.weights = torch.from_numpy(init_weights)
    #self.weights = nn.Parameter(torch.Tensor(1, num_nodes))  # trainable parameter

  def forward(self, x):
    # assuming x is of size num_inst-1-num_nodes
    return x * self.weights  # element-wise multiplication

# Class gradient-based neural diversity machine
class GBNDM(nn.Module):   
    def __init__(self, a_chromosome):   # assuming MNIST
        super(GBNDM, self).__init__()

        # --------- Pre-branch layers 
        self.chromosome = a_chromosome
        self.pre_branch_layers = nn.ModuleList()
        prev_num_out = 28*28
        chrom_ind = 5 # skip over 3 learning rate param., 1 moment. p. (interp./used in training)
        # and 1 exist-or-not (may use in future versions).
        # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
        for i in range(limits['max_pre_branch_layers']):
          
          # Extract and interpret parameters
          layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
          layer_params_real = self.interp_layer_param(layer_params_raw)
        
          # Decide on whether to create a layer or not
          if i==0:  # the first layer of each segment is done by default
            do_layer = True
          else:
            do_layer = layer_params_real[0]

          if do_layer:
            # Create layer    
            a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
            # Append layer and update chromosome index
            self.pre_branch_layers.append(a_layer)
            
          chrom_ind += 6

        # --------- Branches
        num_out_pre_branch = prev_num_out

        self.branches = nn.ModuleList()

        # Scan over branches
        final_num_nodes = []  # keep track of the size of the final layer of each branch
        count_branches = 0
        for bi in range(limits['max_branches']):

          # Initialize branch
          branch_layers = nn.ModuleList()

          # Do branch? Always do the first one by default
          if (a_chromosome[chrom_ind] < args['prob_sel_branch']) or (bi == 0):
            do_branch = True
          else: 
            do_branch = False
            
          chrom_ind += 1

          # Scan over branch layers

          if do_branch:  # if doing branch

            this_fin_num_nodes = 0

            count_branches += 1
            
            for li in range(limits['max_branch_layers']):

              # Extract and interpret parameters
              layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
              layer_params_real = self.interp_layer_param(layer_params_raw)

              # Decide on whether to create a layer or not
              if li==0:  # the first layer of each branch is done by default
                do_layer = True
                prev_num_out = num_out_pre_branch
              else:
                do_layer = layer_params_real[0]

              if do_layer:
                # print('... temp ... this_fin_num_nodes: {}.'.format(this_fin_num_nodes))
                # Create layer    
                a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
                # Num_nodes - keep storing the latest one; the last latest is the final layer num_nodes
                this_fin_num_nodes = prev_num_out
                # Append layer and update chromosome index
                branch_layers.append(a_layer)

              chrom_ind += 6

            # Append branch
            final_num_nodes.append(this_fin_num_nodes)
            #print('final_num_nodes: {}.'.format(final_num_nodes))
            self.branches.append(branch_layers)

          else: # if not doing branch you still need to increment chromosome index

            chrom_ind += 6*limits['max_branch_layers']

        self.num_branches = count_branches
        self.dc_prob_activ = 1 - args['dc_prob_drop'] # probability of using a circuit
        self.tot_nodes_branch_final = sum(final_num_nodes)
        
        # --------- Post-branch layers

        prev_num_out = self.tot_nodes_branch_final
        
        # --- Create post-branch layers

        chrom_ind += 1  # skip over the parameter pertaining to the existence or not of the post-branch segment

        self.post_branch_layers = nn.ModuleList()
        
        # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
        for li in range(limits['max_post_branch_layers']):
          
          # Extract and interpret parameters
          layer_params_raw = a_chromosome[chrom_ind:chrom_ind+6]
          layer_params_real = self.interp_layer_param(layer_params_raw)
        
          # Decide on whether to create a layer or not
          if li==0:  # the first layer of each segment is done by default
            do_layer = True
          else:
            do_layer = layer_params_real[0]

          if do_layer:
            # Create layer    
            a_layer, prev_num_out = self.create_layer(prev_num_out, layer_params_real)
            # Append layer and update chromosome index
            self.post_branch_layers.append(a_layer)
            
          chrom_ind += 6

        # Create a final layer
        self.final_layer = nn.Linear(prev_num_out, 10)

    def forward(self, x, dc_mask = None):
        
        x = x.view(-1, 28*28)

        # Apply pre-branch layers
        for pi, a_layer in enumerate(self.pre_branch_layers):
          #print('Pre-layer {}'.format(pi))
          # if isinstance(a_layer, Elem_Scaling_1D):
          #   set_trace()
          x = a_layer(x)

        # Apply branches
        branch_finals = []
        for bi, a_branch in enumerate(self.branches):
          #print('Branch {}'.format(bi))
          
          z = x

          for a_layer in a_branch:
            # if isinstance(a_layer, Elem_Scaling_1D):
            #   set_trace()
            z = a_layer(z)
          
          if self.training:
            z = (dc_mask[bi] * z) / self.dc_prob_activ  # if training apply DropCircuit
          
          branch_finals.append(z)

        # Concatenate multi-branch final layers
        x = torch.cat(branch_finals,dim=1)

        # if not(self.training): # if not training then testing/evaluating
        #   x = self.dc_prob_activ * x  # scaling due to DropCircuit
      

        # Apply post-branch layers
        for pi, a_layer in enumerate(self.post_branch_layers):
          #print('Post-layer: {}'.format(pi))
          # if isinstance(a_layer, Elem_Scaling_1D):
          #   set_trace()
          x = a_layer(x)

        # Apply final layer
        x = self.final_layer(x)
               
        return F.log_softmax(x, dim=1)


    # Method for interpreting layer parameters
    # Each layer is [exist-or-not, id-or-linear, activation function (AF), 2 AF parameters, number of nodes → total: 6 parameters]
    def interp_layer_param(self, layer_params_raw):
      # Exist or not
      if layer_params_raw[0] < 0.5:
        exist = False
      else:
        exist = True
      # Weight function
      tot_weight_func = 3
      if layer_params_raw[1] < 0.6: # or ... (1/tot_weight_func):  
        weight_func_sel = 'linear'
      elif layer_params_raw[1] < 0.8: # or ... (2/tot_weight_func):
        weight_func_sel = 'elem_scale'
      else:
        weight_func_sel = 'id'
      # activation function
      tot_node_func = 22
      if layer_params_raw[2] < (1/tot_node_func):
        activ_func = 'ReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (2/tot_node_func):
        activ_func = 'Hardshrink'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (3/tot_node_func):
        activ_func = 'Hardtanh'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,2)
        if param_1 > param_2:  # param_1 is min_val; param_2 is max_val
          tmp_val = param_1
          param_1 = param_2
          param_2 = tmp_val
        elif param_1 == param_2:
          param_2 += 0.1
      elif layer_params_raw[2] < (4/tot_node_func):
        activ_func = 'LeakyReLU'
        param_1 = scale_to_range(layer_params_raw[3],0,1)
        param_2 = -1
      elif layer_params_raw[2] < (5/tot_node_func):
        activ_func = 'LogSigmoid'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (6/tot_node_func):
        activ_func = 'PReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (7/tot_node_func):
        activ_func = 'ELU'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (8/tot_node_func):
        activ_func = 'ReLU6'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (9/tot_node_func):
        activ_func = 'RReLU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (10/tot_node_func):
        activ_func = 'SELU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (11/tot_node_func):
        activ_func = 'CELU'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (12/tot_node_func):
        activ_func = 'GELU'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (13/tot_node_func):
        activ_func = 'Sigmoid'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (14/tot_node_func):
        activ_func = 'Softplus'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,40)
      elif layer_params_raw[2] < (15/tot_node_func):
        activ_func = 'Softshrink'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = -1
      elif layer_params_raw[2] < (16/tot_node_func):
        activ_func = 'Softsign'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (17/tot_node_func):
        activ_func = 'Tanh'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (18/tot_node_func):
        activ_func = 'Tanhshrink'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (19/tot_node_func):
        activ_func = 'Threshold'
        param_1 = scale_to_range(layer_params_raw[3],0,2)
        param_2 = scale_to_range(layer_params_raw[4],0,2)
      elif layer_params_raw[2] < (20/tot_node_func):
        activ_func = 'Softmin'
        param_1 = -1
        param_2 = -1
      elif layer_params_raw[2] < (21/tot_node_func):
        activ_func = 'Softmax'
        param_1 = -1
        param_2 = -1
      else: 
        activ_func = 'None'
        param_1 = -1
        param_2 = -1

      # number of nodes
      num_nodes = scale_to_range(layer_params_raw[5], limits['min_layer_nodes'], limits['max_layer_nodes'])
      num_nodes = num_nodes.astype(int)

      return (exist, weight_func_sel, activ_func, param_1, param_2, num_nodes)

    # Method for creating a layer
    # layer_params_real format: (exist, weight_func_sel, activ_func, param_1, param_2, num_nodes)
    def create_layer(self, prev_num_out, layer_params_real):
      
      exist, weight_func_sel, activ_func, param_1, param_2, num_nodes = layer_params_real
      
      # wf_param1/wf_param2 --> not elegant 
      if weight_func_sel == 'linear':
        weight_func = nn.Linear
        num_nodes_in = prev_num_out
        num_nodes_out = num_nodes
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
      elif weight_func_sel == 'id':
        weight_func = nn.Identity
        num_nodes_in = prev_num_out
        num_nodes_out = prev_num_out
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
      else:  # 'elem_scale'
        weight_func = Elem_Scaling_1D
        num_nodes_in = prev_num_out
        num_nodes_out = prev_num_out
        wf_param1 = num_nodes_in
        wf_param2 = num_nodes_out
        
      if activ_func == 'ReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU())
      elif activ_func == 'Hardshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Hardshrink(param_1))
      elif activ_func == 'Hardtanh':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Hardtanh(param_1, param_2))
      elif activ_func == 'LeakyReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.LeakyReLU(param_1))
      elif activ_func == 'LogSigmoid':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.LogSigmoid())
      elif activ_func == 'PReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.PReLU())
      elif activ_func == 'ELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ELU(param_1))
      elif activ_func == 'ReLU6':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU6())
      elif activ_func == 'RReLU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.RReLU())
      elif activ_func == 'SELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.SELU())
      elif activ_func == 'CELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.CELU(param_1))
      elif activ_func == 'GELU':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.ReLU())  # for some reason GELU is not present; revert later if relevant
      elif activ_func == 'Sigmoid':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Sigmoid())
      elif activ_func == 'Softplus':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softplus(param_1, param_2))
      elif activ_func == 'Softshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softplus(param_1))
      elif activ_func == 'Softsign':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softsign())
      elif activ_func == 'Tanh':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Tanh())
      elif activ_func == 'Tanhshrink':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Tanhshrink())
      elif activ_func == 'Threshold':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Threshold(param_1, param_2))
      elif activ_func == 'Softmin':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softmin())
      elif activ_func == 'Softmax':
        a_layer = nn.Sequential(
            weight_func(wf_param1, wf_param2),
            nn.Softmax())
      else:
        a_layer = weight_func(wf_param1, wf_param2)

      return a_layer, num_nodes_out


# Generate a random chromosome where each param. is \in [0,1)
def gen_rand_chromosome(num_param):
  chrom = np.random.rand(num_param)
  return chrom

# ==========================
# Train and test functions
# ==========================

# Create a random mask for DropCircuit
def make_mask(num_circuits, prob_drop):
  rand_vals = np.random.rand(num_circuits)
  decisions = rand_vals >= prob_drop
  a_mask = np.ones(num_circuits)*decisions
  # Must have at least one circuit active
  if np.sum(a_mask) == 0:
    rand_index = np.random.randint(num_circuits)
    a_mask[rand_index] = 1.0

  return torch.from_numpy(a_mask)

def train_one_epoch(a_model, optimizer, epoch, batches):

  a_model.train()
  for batch_idx, (data, target) in enumerate(batches):
      if args['cuda']:
          data, target = data.cuda(), target.cuda()
      # Variables in Pytorch are differentiable. 
      
      data, target = Variable(data), Variable(target)
      #This will zero out the gradients for this batch. 
      optimizer.zero_grad()
      
      # Create DropCircuit mask
      dc_mask = make_mask(a_model.num_branches, args['dc_prob_drop'])
      
      output = a_model(data, dc_mask)

      # Calculate the negative log likelihood loss.
      loss = F.nll_loss(output, target)
      #dloss/dx for every Variable 
      loss.backward()
      # Gradient clipping
      torch.nn.utils.clip_grad_norm_(a_model.parameters(), args['clip_level'])
      #to do a one-step update on our parameter.
      optimizer.step()
      #Print out the loss periodically. 

  if args['verbose_train']:
    if epoch % args['log_interval_epoch'] == 0:
      print('Epoch: {}. Latest loss: {}.'.format(epoch, loss.data))

# Compute accuracy
# The argument (data_source) of this function can be a data_loader or a list of batches (previously extracted) 
def comp_accuracy(a_model, data_source, src_num_instances):
    a_model.eval()
    a_loss = 0
    correct = 0
    preds = torch.zeros(0)
    first = True
    for a_data_in, a_data_out in data_source:
        if args['cuda']:
            a_data_in, a_data_out = a_data_in.cuda(), a_data_out.cuda()
        a_data_in, a_data_out = Variable(a_data_in), Variable(a_data_out)
        output = a_model(a_data_in)

        a_loss += F.nll_loss(output, a_data_out, reduction='sum').data # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        if first:
          preds = pred
          first = False
        else:
          preds = torch.cat((preds, pred),0)

        correct += pred.eq(a_data_out.data.view_as(pred)).long().cpu().sum()

    # Compute and return accuracy
    if type(data_source) == list:  # case: list of batches
      result = 100. * (correct.numpy()/ src_num_instances)
    else: # case: data_loader
      result = 100. * (correct.numpy()/ len(data_source.dataset))
    return result



# ==========================
# Train and test functions
# ==========================

# Compute the number of parameters in a chromose (depends on limits)
def comp_num_chrom_param(limits):
  # Num. of training parameters
  tot_train_param = 4 # lr1, lr2, lr2 prop, momentum
  # Num. of pre-branch parameters
  tot_pre_branch = 1+(6*limits['max_pre_branch_layers']) # exist-or-not, layer params.
  # Num. of branch parameters
  tot_branch = (1+(6*limits['max_branch_layers']))*limits['max_branches']
  # Num. of post-branch parameters
  tot_post_branch = 1+(6*limits['max_post_branch_layers'])

  return tot_train_param+tot_pre_branch+tot_branch+tot_post_branch

# Interpret learning rate and momentum parameters
def interp_lrm(params):
  lr1 = scale_to_range(params[0], limits['lr1_min'], limits['lr1_,max'])
  lr2 = scale_to_range(params[1], limits['lr2_min'], limits['lr2_,max'])
  if lr1 < lr2:
    temp = lr1
    lr1 = lr2
    lr2 = temp
  lr2_epoch = (np.round(params[2]*args['num_epochs_search'])).astype(int)
  a_decr = (lr1-lr2)/lr2_epoch
  a_momentum = scale_to_range(params[3], limits['moment_min'], limits['moment_max'])
  return lr1, lr2, lr2_epoch, a_momentum, a_decr

# Chromosome evaluation (more efficient than do_training)
# Function to train a specific model
# Early stopping, or returning best validation model, is not implemented 
def do_eval_chrom(a_model, train_params, num_epochs):

  # Extract basic information
  lr1, lr2, lr2_epoch, a_momentum, lr_decr = train_params  
  args['lr'] = lr1
  args['momentum'] = a_momentum
  
  optimizer = optim.SGD(a_model.parameters(), lr=args['lr'], momentum=args['momentum'])
  valid_accurs = []
  train_accurs = []
  train_start_time = time.time()
  for epoch in range(1, num_epochs + 1):

    if args['verbose_train']:
      print('Epoch {} learning rate: {}.'.format(epoch, args['lr']))

    train_one_epoch(a_model, optimizer, epoch, train_batches)
    
    a_train_accur = comp_accuracy(a_model, train_batches, num_train_instances)
    if args['verbose_train']:
      print('Training accuracy: {}%.'.format(a_train_accur))
    train_accurs.append(a_train_accur)
    
    a_valid_accur = comp_accuracy(a_model, valid_batches, num_valid_instances)
    if args['verbose_train']:
      print('Validation accuracy: {}%.'.format(a_valid_accur))
    valid_accurs.append(a_valid_accur)

    # Decrement learning rate
    if epoch < lr2_epoch:
        args['lr'] -= lr_decr
        for param_group in optimizer.param_groups:
          param_group['lr'] = args['lr']

  train_elapsed_time = time.time() - train_start_time
  print('The training process took {} seconds.'.format(train_elapsed_time))

  return a_model, valid_accurs, train_accurs

# Function to train a specific model
# Early stopping, or returning best validation model, is not implemented 
def do_training(a_model, train_params, num_epochs):

  lr1, lr2, lr2_epoch, a_momentum, lr_decr = train_params  
  args['lr'] = lr1
  args['momentum'] = a_momentum

  optimizer = optim.SGD(a_model.parameters(), lr=args['lr'], momentum=args['momentum'])
  best_valid_accur = 0
  best_model = type(a_model)(a_model.chromosome) # get a new instance
  valid_accurs = []
  train_accurs = []
  train_start_time = time.time()
  for epoch in range(1, num_epochs + 1):

    if args['verbose_train']:
      print('Epoch {} learning rate: {}.'.format(epoch, args['lr']))

    train_one_epoch(a_model, optimizer, epoch, train_batches)
    
    a_train_accur = comp_accuracy(a_model, train_batches, num_train_instances)
    if args['verbose_train']:
      print('Training accuracy: {}%.'.format(a_train_accur))
    train_accurs.append(a_train_accur)
    
    a_valid_accur = comp_accuracy(a_model, valid_batches, num_valid_instances)
    if args['verbose_train']:
      print('Validation accuracy: {}%.'.format(a_valid_accur))
    valid_accurs.append(a_valid_accur)
    if a_valid_accur > best_valid_accur:
      best_valid_accur = a_valid_accur
      # best_model.load_state_dict(a_model.state_dict()) # copy weights and stuff
      best_model = copy.deepcopy(a_model)

    # Decrement learning rate
    if epoch < lr2_epoch:
        args['lr'] -= lr_decr
        for param_group in optimizer.param_groups:
          param_group['lr'] = args['lr']

  train_elapsed_time = time.time() - train_start_time
  print('The training process took {} seconds.'.format(train_elapsed_time))

  if args['cuda']:
      best_model.cuda()

  return a_model, best_model, valid_accurs, train_accurs

  # ================================
  # Architectureal search
  # ================================

  # Artificial Intelligence Methods students should focus on the code below.
  # You should keep the neural network code unchaged. This is crucial for 
  # comparison purposes. In other words, focus only on modifying the architecture
  # search code below.

  # --- Architectural search parameters
  meta = {}
  meta['max_rs_iter'] = 10 # 10  # initial random search
  meta['max_shc_iter'] = 20 # 40 # 20 # 40  # stochastic hill climbing iterations
  meta['num_neighbours'] = 8 # 16 
  meta['neighbour_range'] = 0.4  # 0.2  # mutation rate for stochastic hill-climbing
  meta['num_differential_sol'] = 4 # 8 # number of differential evolution solutions
  meta['diff_lr'] = 0.5 # 0.1 # learning rate for differential search

  meta_rs_valids = []
  best_model = None
  best_chromosome = None
  best_model_accur = 0

  # Prepare model
  def prepare_model(a_rand_chrom):
    # Initialize chromosome and model
    model = GBNDM(a_rand_chrom)
    
    if args['cuda']:
        model.cuda()

    # Interpret learning rates and momentum
    lr1, lr2, lr2_epoch, a_momentum, lr_decr = interp_lrm(a_rand_chrom[0:4])
    train_params = (lr1, lr2, lr2_epoch, a_momentum, lr_decr)
    args['momentum'] = a_momentum
    if args['verbose_train']:
      print('lr1: {}'.format(lr1))
      print('lr2: {}'.format(lr2))
      print('lr2_epoch: {}'.format(lr2_epoch))
      print('a_momentum: {}'.format(a_momentum))
      print('a_decr: {}'.format(a_decr))

    return model, train_params

  # Start with a small random search
  print('Initital random search ...')
  for rsi in range(meta['max_rs_iter']):

    if args['verbose_meta']:
      print('Search iteration {}.'.format(rsi+1))

    num_chrom_param = comp_num_chrom_param(limits)
    
    a_rand_chrom = gen_rand_chromosome(num_chrom_param)

    # --- Actual training
    model, train_params = prepare_model(a_rand_chrom)
    model, valid_accurs, train_accurs = do_eval_chrom(model, train_params, args['num_epochs_search'])
    best_valid_accur = max(valid_accurs)
    print('Best validation accuracy: {}%.'.format(best_valid_accur))

    # Store best model
    if best_valid_accur > best_model_accur:
      best_model_accur = best_valid_accur
      best_model = model
      best_train_params = train_params
      best_chromosome = a_rand_chrom

    meta_rs_valids.append(best_valid_accur)

  print('*****************************************************')
  print('Best accuracy after initial random search: {}'.format(best_model_accur))
  print('*****************************************************')

  if args['verbose_meta']:
    print('Best validation errors:')
    print(meta_rs_valids)

  # # --- Stochastic hill climbing

  num_chrom_params = best_chromosome.shape[0]

  # Function for creating one neighbour
  def create_a_neighbour(a_chromosome, neighbour_range, num_chrom_params):
    # Create mutation vector
    mutat_vec = (np.random.rand(num_chrom_params)*neighbour_range)-(neighbour_range/2)
    # Add mutation vector
    new_chromosome = a_chromosome + mutat_vec
    # Clip
    np.clip(new_chromosome, 0, 0.99999999999, out=new_chromosome)

    return new_chromosome

  # Evaluate a list of chromosomes
  def eval_chromosomes(list_chromosomes,num_chrom_params):
    
    # best_model_accur, best_chromosome, best_model, best_train_params = best_res
    
    best_model_accur = 0
    best_chromosome = None
    best_model = None
    best_train_params = None


    num_chrom = len(list_chromosomes)
    mat_chrom_acur = np.zeros((num_chrom, 1+num_chrom_params))
    neighb_valid_accurs = []

    for ci, a_chrom in enumerate(list_chromosomes):
      if args['verbose_meta']:
        print('Chromosome {} ...'.format(ci))
      # --- Actual training
      model, train_params = prepare_model(a_chrom)
      model, valid_accurs, train_accurs = do_eval_chrom(model, train_params, args['num_epochs_search'])
      best_valid_accur = max(valid_accurs)
      # Store chromosome and accuracy
      mat_chrom_acur[ci,0] = best_valid_accur
      mat_chrom_acur[ci,1:] = a_chrom
      print('Best validation accuracy: {}%.'.format(best_valid_accur))
      neighb_valid_accurs.append(best_valid_accur)
      if best_valid_accur > best_model_accur:
        best_model_accur = best_valid_accur
        best_chromosome = a_chrom
        best_model = model
        best_train_params = train_params
        if args['verbose_meta']:
          print('*** Improving validation accuracy: {}.'.format(best_model_accur))

    best_res = (best_model_accur, best_chromosome, best_model, best_train_params)
    return best_res, mat_chrom_acur
        
      
  # Function for creating a list of neighbours
  def create_neighbours(a_chromosome, meta, num_chrom_params):
    neighbours = []
    # Scan through number of neighbours
    for ni in range(meta['num_neighbours']):
      # Create neighbour
      a_neighb = create_a_neighbour(a_chromosome, meta['neighbour_range'], num_chrom_params)
      # Append neighbour
      neighbours.append(a_neighb)

    return neighbours

  # Simple differential search
  def do_diff_chrom_v1(mat_chrom_accur, num_new_sol):
    
    # Initialize new chromosomes
    num_chrom = mat_chrom_accur.shape[0]
    if num_new_sol >= num_chrom:
      num_new_sol = num_chrom-1
    new_chromosomes = []

    # Sort the array of chromosomes based on the first column (contains accur.)
    mat_chrom_accur = mat_chrom_accur[(-mat_chrom_accur[:,0]).argsort()]
    # print(mat_chrom_accur[:,0:4])
    # Extract first/best chromosome
    best_chrom = mat_chrom_accur[0,1:]
    # Scan through new solutions
    for si in range(num_new_sol):  
      # Extract next best chrom
      next_best_chrom = mat_chrom_accur[1+si,1:]
      # Compute differential
      a_diff = best_chrom - next_best_chrom
      # Add differential whilst applying a learning rate
      a_new_chrom = best_chrom + (meta['diff_lr']*a_diff)
      np.clip(a_new_chrom, 0, 0.99999999999, out=a_new_chrom)
      # Store new solution 
      new_chromosomes.append(a_new_chrom)

    return new_chromosomes


  # Architectural search iterations

  best_res = (best_model_accur, best_chromosome, best_model, best_train_params)

  meta_start_time = time.time()
  for shci in range(meta['max_shc_iter']):

    best_model_accur, best_chromosome, best_model, best_train_params = best_res

    if args['verbose_meta']:
      print('======================================')
      print('Stochastic hill-climbing iteration {}.'.format(shci))
      print('======================================')
      print('Best accuracy so far: {}'.format(best_model_accur))
      print('======================================')
    # --- Create a set of stochastic neighbours from the current best model
    chrom_neighbors = create_neighbours(best_chromosome, meta, num_chrom_params)
    # Test validation accuracies of neighbours
    new_res, mat_chrom_acur = eval_chromosomes(chrom_neighbors,num_chrom_params)
    if new_res[0] > best_res[0]:
      best_res = new_res
    print('***********************************************')
    print('Best accuracy after random mutation: {}'.format(new_res[0]))
    print('***********************************************')
    
    # --- Simple differential search
    print('***** Differential Search *********************')
    diff_chromosomes = do_diff_chrom_v1(mat_chrom_acur, meta['num_differential_sol'])
    new_res, mat_chrom_acur = eval_chromosomes(diff_chromosomes,num_chrom_params)
    if new_res[0] > best_res[0]:
      best_res = new_res
    print('***********************************************')
    print('Best accuracy after differential search: {}'.format(new_res[0]))
    print('***********************************************')

  meta_elapsed_time = time.time() - meta_start_time
  if args['verbose_meta']:
    print('=====================================================')
    print('Architectural optimization total time: {}.'.format(meta_elapsed_time))
    print('=====================================================')
    

  # ==========================
  # Test final model / Visualize predictions
  # ==========================

  def final_test(a_model):
      a_model.eval()
      test_loss = 0
      correct = 0
      test_preds = torch.zeros(0)
      first = True
      for test_data_in, test_data_out in test_loader: 

          if args['cuda']:
              test_data_in, test_data_out = test_data_in.cuda(), test_data_out.cuda()
                  
          test_data_in, test_data_out = Variable(test_data_in), Variable(test_data_out)
          output = a_model(test_data_in)
          test_loss += F.nll_loss(output, test_data_out, reduction='sum').data # sum up batch loss

          pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
          if first:
            test_preds = pred
            first = False
          else:
            test_preds = torch.cat((test_preds, pred),0)

          correct += pred.eq(test_data_out.data.view_as(pred)).long().cpu().sum()

      # Print test accuracy
      test_loss /= len(test_loader.dataset)
      accuracy = 100. * correct / len(test_loader.dataset)
      print('\nTest set: Average loss: {:.4f}, Accuracy (at final epoch): {}/{} ({:.0f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset), accuracy))

      return accuracy

  # Final visualization
  print('======================================')
  print('Best accuracy so far: {}'.format(best_res[0]))
  print('======================================')
  print('Computing the final test ...')
  best_model_accur, best_chromosome, best_model, best_train_params = best_res
  final_model, best_valid_model, valid_accurs, train_accurs = do_training(best_model, best_train_params, args['num_epochs_test'])
  print('=====================================')
  print('Training accuracies')
  print('=====================================')
  print(train_accurs)
  print('=====================================')
  print('Best training parameters')
  print('=====================================')
  print(best_train_params)
  print('=====================================')
  print('Best model')
  print('=====================================')
  print(best_valid_model)
  print('=====================================')
  print('Test accuracies')
  print('=====================================')
  print('Model with best validation accuracy: ')
  accur_valid = final_test(best_valid_model)
  print('Model at the end of training: ')
  accur_final = final_test(final_model)

  max_accur = int(max(accur_valid, accur_final))
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision) (1.17.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (6.2.2)
# Data extraction trial 0.
# Data extraction trial 1.
# Initital random search ...
# Search iteration 1.
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:100: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# The training process took 0.27838897705078125 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 2.
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:100: UserWarning: Implicit dimension choice for softmin has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# The training process took 0.30198240280151367 seconds.
# Best validation accuracy: 10.9%.
# Search iteration 3.
# The training process took 0.21570062637329102 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 4.
# The training process took 0.29346275329589844 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 5.
# The training process took 0.1947646141052246 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 6.
# The training process took 0.3745615482330322 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 7.
# The training process took 0.2969930171966553 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 8.
# The training process took 0.33357858657836914 seconds.
# Best validation accuracy: 9.8%.
# Search iteration 9.
# The training process took 0.24292230606079102 seconds.
# Best validation accuracy: 10.7%.
# Search iteration 10.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:780: RuntimeWarning: divide by zero encountered in double_scalars
# The training process took 0.3810081481933594 seconds.
# Best validation accuracy: 9.8%.
# *****************************************************
# Best accuracy after initial random search: 10.9
# *****************************************************
# Best validation errors:
# [10.7, 10.9, 10.7, 9.8, 10.7, 9.8, 9.8, 9.8, 10.7, 9.8]
# ======================================
# Stochastic hill-climbing iteration 0.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.35692691802978516 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.26200079917907715 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.256990909576416 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 3 ...
# The training process took 0.33382225036621094 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.3242621421813965 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.3077552318572998 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.27311229705810547 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 7 ...
# The training process took 0.3364899158477783 seconds.
# Best validation accuracy: 10.0%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.34885096549987793 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 1 ...
# The training process took 0.3323214054107666 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.30685901641845703 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 3 ...
# The training process took 0.3331913948059082 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 1.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.3478240966796875 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.32028937339782715 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.3449118137359619 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.2738606929779053 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.28763914108276367 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.29017019271850586 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.27313923835754395 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.3088700771331787 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.3090951442718506 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.2566049098968506 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.32320690155029297 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 3 ...
# The training process took 0.2695012092590332 seconds.
# Best validation accuracy: 10.0%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 2.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.2833108901977539 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.2995328903198242 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 2 ...
# The training process took 0.27387404441833496 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.3193211555480957 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 4 ...
# The training process took 0.2937324047088623 seconds.
# Best validation accuracy: 10.5%.
# Chromosome 5 ...
# The training process took 0.2754826545715332 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.2993006706237793 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.25764036178588867 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.259138822555542 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.30693721771240234 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3030991554260254 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.33301210403442383 seconds.
# Best validation accuracy: 10.0%.
# ***********************************************
# Best accuracy after differential search: 10.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 3.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.3050272464752197 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.2682046890258789 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.2766907215118408 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.343367338180542 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.33339452743530273 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.29238438606262207 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 6 ...
# The training process took 0.2608480453491211 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.31261491775512695 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.28398585319519043 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.3152592182159424 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 2 ...
# The training process took 0.278672456741333 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.32918691635131836 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 4.
# ======================================
# Best accuracy so far: 10.9
# ======================================
# Chromosome 0 ...
# The training process took 0.3010566234588623 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.3009824752807617 seconds.
# Best validation accuracy: 14.2%.
# *** Improving validation accuracy: 14.2.
# Chromosome 2 ...
# The training process took 0.3093106746673584 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.3028285503387451 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.3366127014160156 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.34932398796081543 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.2819366455078125 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.2764744758605957 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 14.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.3000807762145996 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.3163435459136963 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.3022620677947998 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 3 ...
# The training process took 0.31450986862182617 seconds.
# Best validation accuracy: 10.8%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 5.
# ======================================
# Best accuracy so far: 14.2
# ======================================
# Chromosome 0 ...
# The training process took 0.27933287620544434 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.34750890731811523 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.32439589500427246 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 3 ...
# The training process took 0.31863880157470703 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.34743618965148926 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.3244595527648926 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 6 ...
# The training process took 0.32787036895751953 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.33490824699401855 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.30167579650878906 seconds.
# Best validation accuracy: 14.7%.
# *** Improving validation accuracy: 14.7.
# Chromosome 1 ...
# The training process took 0.353879451751709 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.32221364974975586 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.3031604290008545 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 14.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 6.
# ======================================
# Best accuracy so far: 14.7
# ======================================
# Chromosome 0 ...
# The training process took 0.33124709129333496 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.2854197025299072 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3004634380340576 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 3 ...
# The training process took 0.29186129570007324 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 4 ...
# The training process took 0.30952954292297363 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 5 ...
# The training process took 0.28523993492126465 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.2701094150543213 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.23747038841247559 seconds.
# Best validation accuracy: 11.0%.
# *** Improving validation accuracy: 11.0.
# ***********************************************
# Best accuracy after random mutation: 11.0
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.23381495475769043 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.2766571044921875 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.2614166736602783 seconds.
# Best validation accuracy: 10.5%.
# Chromosome 3 ...
# The training process took 0.2556343078613281 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.9
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 7.
# ======================================
# Best accuracy so far: 14.7
# ======================================
# Chromosome 0 ...
# The training process took 0.3246946334838867 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.3155333995819092 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.2689788341522217 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.2827591896057129 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 4 ...
# The training process took 0.2716400623321533 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.2618546485900879 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 6 ...
# The training process took 0.30321502685546875 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 7 ...
# The training process took 0.24279999732971191 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.3300211429595947 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.3378410339355469 seconds.
# Best validation accuracy: 20.599999999999998%.
# *** Improving validation accuracy: 20.599999999999998.
# Chromosome 2 ...
# The training process took 0.3218684196472168 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.32804107666015625 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after differential search: 20.599999999999998
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 8.
# ======================================
# Best accuracy so far: 20.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.32732295989990234 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.33194661140441895 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3254129886627197 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 3 ...
# The training process took 0.3343362808227539 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.3178701400756836 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.3306093215942383 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.33248209953308105 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.3469853401184082 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.34265589714050293 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.3156557083129883 seconds.
# Best validation accuracy: 10.5%.
# *** Improving validation accuracy: 10.5.
# Chromosome 2 ...
# The training process took 0.2903280258178711 seconds.
# Best validation accuracy: 30.599999999999998%.
# *** Improving validation accuracy: 30.599999999999998.
# Chromosome 3 ...
# The training process took 0.3199138641357422 seconds.
# Best validation accuracy: 20.0%.
# ***********************************************
# Best accuracy after differential search: 30.599999999999998
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 9.
# ======================================
# Best accuracy so far: 30.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.3296217918395996 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.3023996353149414 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 2 ...
# The training process took 0.32436299324035645 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 3 ...
# The training process took 0.30890917778015137 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.3305795192718506 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.31682515144348145 seconds.
# Best validation accuracy: 21.4%.
# *** Improving validation accuracy: 21.4.
# Chromosome 6 ...
# The training process took 0.32829761505126953 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.3080105781555176 seconds.
# Best validation accuracy: 10.0%.
# ***********************************************
# Best accuracy after random mutation: 21.4
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.28654980659484863 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 1 ...
# The training process took 0.2830171585083008 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.2856101989746094 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 3 ...
# The training process took 0.2769753932952881 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 10.
# ======================================
# Best accuracy so far: 30.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.26185059547424316 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.31301450729370117 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3150327205657959 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.31874680519104004 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 4 ...
# The training process took 0.3223154544830322 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.2959632873535156 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.28597068786621094 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.31012773513793945 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.27922987937927246 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.31474757194519043 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3325328826904297 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.31090331077575684 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 11.
# ======================================
# Best accuracy so far: 30.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.25869011878967285 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.3108682632446289 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.28400301933288574 seconds.
# Best validation accuracy: 12.8%.
# *** Improving validation accuracy: 12.8.
# Chromosome 3 ...
# The training process took 0.2612648010253906 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 4 ...
# The training process took 0.3030426502227783 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.2835812568664551 seconds.
# Best validation accuracy: 16.5%.
# *** Improving validation accuracy: 16.5.
# Chromosome 6 ...
# The training process took 0.26531171798706055 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.282529354095459 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after random mutation: 16.5
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.24593758583068848 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 1 ...
# The training process took 0.24594354629516602 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.2828242778778076 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 3 ...
# The training process took 0.24817442893981934 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 12.
# ======================================
# Best accuracy so far: 30.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.2951533794403076 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.2887871265411377 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 2 ...
# The training process took 0.3117184638977051 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.2931549549102783 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 4 ...
# The training process took 0.32491350173950195 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 5 ...
# The training process took 0.2779362201690674 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.3009328842163086 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 7 ...
# The training process took 0.32343316078186035 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after random mutation: 10.9
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.26027798652648926 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.2767608165740967 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.2602498531341553 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.2741563320159912 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 9.8
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 13.
# ======================================
# Best accuracy so far: 30.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.3187599182128906 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.34926795959472656 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3740074634552002 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.30273914337158203 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.29790663719177246 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.2785193920135498 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.2977254390716553 seconds.
# Best validation accuracy: 10.5%.
# Chromosome 7 ...
# The training process took 0.34487271308898926 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.2948603630065918 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.27863216400146484 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.21707487106323242 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 3 ...
# The training process took 0.23067498207092285 seconds.
# Best validation accuracy: 21.7%.
# *** Improving validation accuracy: 21.7.
# ***********************************************
# Best accuracy after differential search: 21.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 14.
# ======================================
# Best accuracy so far: 30.599999999999998
# ======================================
# Chromosome 0 ...
# The training process took 0.3177335262298584 seconds.
# Best validation accuracy: 13.700000000000001%.
# *** Improving validation accuracy: 13.700000000000001.
# Chromosome 1 ...
# The training process took 0.2885866165161133 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.28110313415527344 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.2903311252593994 seconds.
# Best validation accuracy: 15.0%.
# *** Improving validation accuracy: 15.0.
# Chromosome 4 ...
# The training process took 0.30231499671936035 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 5 ...
# The training process took 0.2981252670288086 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.3173842430114746 seconds.
# Best validation accuracy: 10.9%.
# Chromosome 7 ...
# The training process took 0.2817869186401367 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 15.0
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.30715394020080566 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.290280818939209 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 2 ...
# The training process took 0.2923097610473633 seconds.
# Best validation accuracy: 20.200000000000003%.
# *** Improving validation accuracy: 20.200000000000003.
# Chromosome 3 ...
# The training process took 0.2657136917114258 seconds.
# Best validation accuracy: 30.8%.
# *** Improving validation accuracy: 30.8.
# ***********************************************
# Best accuracy after differential search: 30.8
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 15.
# ======================================
# Best accuracy so far: 30.8
# ======================================
# Chromosome 0 ...
# The training process took 0.3178412914276123 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.2977151870727539 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3323659896850586 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 3 ...
# The training process took 0.3113067150115967 seconds.
# Best validation accuracy: 19.6%.
# *** Improving validation accuracy: 19.6.
# Chromosome 4 ...
# The training process took 0.329944372177124 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 5 ...
# The training process took 0.28894901275634766 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.3155202865600586 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.3070871829986572 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 19.6
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.29659318923950195 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# Chromosome 1 ...
# The training process took 0.2985405921936035 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.2780888080596924 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 3 ...
# The training process took 0.25002455711364746 seconds.
# Best validation accuracy: 21.3%.
# *** Improving validation accuracy: 21.3.
# ***********************************************
# Best accuracy after differential search: 21.3
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 16.
# ======================================
# Best accuracy so far: 30.8
# ======================================
# Chromosome 0 ...
# The training process took 0.349839448928833 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.3101470470428467 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.30037808418273926 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.31543731689453125 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.29785633087158203 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.3157804012298584 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.28964996337890625 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.28511691093444824 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.3394622802734375 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.32785820960998535 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.3404510021209717 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.32433128356933594 seconds.
# Best validation accuracy: 10.0%.
# *** Improving validation accuracy: 10.0.
# ***********************************************
# Best accuracy after differential search: 10.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 17.
# ======================================
# Best accuracy so far: 30.8
# ======================================
# Chromosome 0 ...
# The training process took 0.34253501892089844 seconds.
# Best validation accuracy: 10.9%.
# *** Improving validation accuracy: 10.9.
# Chromosome 1 ...
# The training process took 0.3651289939880371 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.3021116256713867 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 3 ...
# The training process took 0.3162407875061035 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 4 ...
# The training process took 0.2953503131866455 seconds.
# Best validation accuracy: 17.2%.
# *** Improving validation accuracy: 17.2.
# Chromosome 5 ...
# The training process took 0.3032858371734619 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.3024001121520996 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.3381838798522949 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after random mutation: 17.2
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.27563023567199707 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.28093433380126953 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 2 ...
# The training process took 0.3041512966156006 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 3 ...
# The training process took 0.29506659507751465 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after differential search: 10.7
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 18.
# ======================================
# Best accuracy so far: 30.8
# ======================================
# Chromosome 0 ...
# The training process took 0.29888129234313965 seconds.
# Best validation accuracy: 15.8%.
# *** Improving validation accuracy: 15.8.
# Chromosome 1 ...
# The training process took 0.31243395805358887 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.27306342124938965 seconds.
# Best validation accuracy: 19.1%.
# *** Improving validation accuracy: 19.1.
# Chromosome 3 ...
# The training process took 0.31801819801330566 seconds.
# Best validation accuracy: 17.1%.
# Chromosome 4 ...
# The training process took 0.275348424911499 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 5 ...
# The training process took 0.2647368907928467 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 6 ...
# The training process took 0.2801048755645752 seconds.
# Best validation accuracy: 20.1%.
# *** Improving validation accuracy: 20.1.
# Chromosome 7 ...
# The training process took 0.32863688468933105 seconds.
# Best validation accuracy: 10.9%.
# ***********************************************
# Best accuracy after random mutation: 20.1
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.26354408264160156 seconds.
# Best validation accuracy: 22.0%.
# *** Improving validation accuracy: 22.0.
# Chromosome 1 ...
# The training process took 0.26415562629699707 seconds.
# Best validation accuracy: 17.2%.
# Chromosome 2 ...
# The training process took 0.2526533603668213 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.2681121826171875 seconds.
# Best validation accuracy: 10.7%.
# ***********************************************
# Best accuracy after differential search: 22.0
# ***********************************************
# ======================================
# Stochastic hill-climbing iteration 19.
# ======================================
# Best accuracy so far: 30.8
# ======================================
# Chromosome 0 ...
# The training process took 0.30031442642211914 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 1 ...
# The training process took 0.36828112602233887 seconds.
# Best validation accuracy: 10.0%.
# Chromosome 2 ...
# The training process took 0.32489800453186035 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 3 ...
# The training process took 0.30525684356689453 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 4 ...
# The training process took 0.268390417098999 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 5 ...
# The training process took 0.29280972480773926 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 6 ...
# The training process took 0.27664923667907715 seconds.
# Best validation accuracy: 10.7%.
# Chromosome 7 ...
# The training process took 0.31264328956604004 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after random mutation: 10.7
# ***********************************************
# ***** Differential Search *********************
# Chromosome 0 ...
# The training process took 0.2587130069732666 seconds.
# Best validation accuracy: 9.8%.
# *** Improving validation accuracy: 9.8.
# Chromosome 1 ...
# The training process took 0.3002634048461914 seconds.
# Best validation accuracy: 9.8%.
# Chromosome 2 ...
# The training process took 0.2825777530670166 seconds.
# Best validation accuracy: 10.7%.
# *** Improving validation accuracy: 10.7.
# Chromosome 3 ...
# The training process took 0.2952432632446289 seconds.
# Best validation accuracy: 9.8%.
# ***********************************************
# Best accuracy after differential search: 10.7
# ***********************************************
# =====================================================
# Architectural optimization total time: 73.65713667869568.
# =====================================================
# ======================================
# Best accuracy so far: 30.8
# ======================================
# Computing the final test ...
# The training process took 27.438780307769775 seconds.
# =====================================
# Training accuracies
# =====================================
# [30.0, 30.0, 48.0, 35.0, 22.0, 19.0, 40.0, 39.0, 35.0, 37.0, 33.0, 38.0, 34.0, 36.0, 6.0, 50.0, 53.0, 33.0, 28.000000000000004, 34.0, 49.0, 59.0, 49.0, 45.0, 42.0, 67.0, 51.0, 54.0, 45.0, 42.0, 35.0, 46.0, 49.0, 39.0, 77.0, 54.0, 67.0, 69.0, 64.0, 63.0, 69.0, 59.0, 76.0, 75.0, 67.0, 80.0, 64.0, 52.0, 67.0, 64.0, 82.0, 63.0, 62.0, 62.0, 75.0, 78.0, 66.0, 77.0, 81.0, 80.0, 73.0, 83.0, 73.0, 79.0, 84.0, 68.0, 74.0, 76.0, 76.0, 88.0, 95.0, 78.0, 90.0, 77.0, 77.0, 73.0, 90.0, 71.0, 96.0, 73.0, 93.0, 95.0, 89.0, 82.0, 81.0, 72.0, 75.0, 74.0, 74.0, 90.0, 91.0, 79.0, 91.0, 92.0, 80.0, 79.0, 87.0, 89.0, 81.0, 90.0, 91.0, 86.0, 93.0, 81.0, 95.0, 97.0, 72.0, 91.0, 86.0, 84.0, 74.0, 82.0, 89.0, 84.0, 82.0, 81.0, 91.0, 97.0, 88.0, 88.0, 89.0, 99.0, 90.0, 97.0, 98.0, 88.0, 99.0, 89.0, 82.0, 84.0, 98.0, 88.0, 96.0, 93.0, 97.0, 100.0, 93.0, 88.0, 90.0, 86.0, 94.0, 100.0, 98.0, 100.0, 87.0, 92.0, 84.0, 93.0, 98.0, 96.0, 85.0, 100.0, 88.0, 94.0, 100.0, 100.0, 87.0, 89.0, 89.0, 97.0, 91.0, 99.0, 99.0, 75.0, 69.0, 91.0, 81.0, 92.0, 100.0, 89.0, 98.0, 98.0, 91.0, 100.0, 90.0, 99.0, 98.0, 97.0, 89.0, 89.0, 91.0, 97.0, 89.0, 92.0, 97.0, 83.0, 91.0, 99.0, 99.0, 91.0, 98.0, 100.0, 99.0, 98.0, 89.0, 89.0, 88.0, 85.0, 90.0, 91.0, 100.0, 91.0, 91.0, 93.0, 98.0, 89.0, 89.0, 88.0, 68.0, 87.0, 73.0, 100.0, 100.0, 94.0, 100.0, 92.0, 84.0, 80.0, 80.0, 85.0, 100.0, 100.0, 83.0, 99.0, 97.0, 89.0, 87.0, 84.0, 100.0, 99.0, 100.0, 95.0, 94.0, 90.0, 100.0, 100.0, 94.0, 100.0, 98.0, 98.0, 96.0, 99.0, 100.0, 89.0, 89.0, 98.0, 99.0, 95.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 97.0, 100.0, 100.0, 93.0, 95.0, 99.0, 94.0, 95.0, 97.0, 100.0, 96.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 31.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 97.0, 100.0, 100.0, 100.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 98.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 97.0, 98.0, 96.0, 99.0, 95.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 93.0, 92.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 95.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 94.0, 96.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 89.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 92.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 99.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 97.0 ...
# =====================================
# Best training parameters
# =====================================
# (1.99999999998001, 1.547459173722881, 3, 0.10760789984528524, 0.15084694208570962)
# =====================================
# Best model
# =====================================
# GBNDM(
#   (pre_branch_layers): ModuleList(
#     (0): Sequential(
#       (0): Identity()
#       (1): SELU()
#     )
#     (1): Linear(in_features=784, out_features=36, bias=True)
#   )
#   (branches): ModuleList(
#     (0): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=36, out_features=50, bias=True)
#         (1): Tanh()
#       )
#       (1): Elem_Scaling_1D()
#       (2): Sequential(
#         (0): Elem_Scaling_1D()
#         (1): Sigmoid()
#       )
#     )
#     (1): ModuleList(
#       (0): Sequential(
#         (0): Elem_Scaling_1D()
#         (1): ReLU()
#       )
#       (1): Sequential(
#         (0): Identity()
#         (1): ReLU()
#       )
#       (2): Linear(in_features=36, out_features=23, bias=True)
#     )
#     (2): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=36, out_features=65, bias=True)
#         (1): LeakyReLU(negative_slope=0.5684611188144716)
#       )
#       (1): Sequential(
#         (0): Identity()
#         (1): LeakyReLU(negative_slope=0.18382954648891128)
#       )
#       (2): Sequential(
#         (0): Identity()
#         (1): ReLU()
#       )
#     )
#     (3): ModuleList(
#       (0): Identity()
#       (1): Sequential(
#         (0): Linear(in_features=36, out_features=21, bias=True)
#         (1): ReLU()
#       )
#     )
#     (4): ModuleList(
#       (0): Sequential(
#         (0): Identity()
#         (1): Softmax(dim=None)
#       )
#       (1): Sequential(
#         (0): Linear(in_features=36, out_features=60, bias=True)
#         (1): LeakyReLU(negative_slope=0.6752443769353276)
#       )
#       (2): Sequential(
#         (0): Identity()
#         (1): ReLU()
#       )
#       (3): Sequential(
#         (0): Identity()
#         (1): Tanhshrink()
#       )
#       (4): Sequential(
#         (0): Linear(in_features=60, out_features=65, bias=True)
#         (1): Softmin()
#       )
#     )
#     (5): ModuleList(
#       (0): Sequential(
#         (0): Linear(in_features=36, out_features=27, bias=True)
#         (1): LeakyReLU(negative_slope=0.5570477339684199)
#       )
#       (1): Sequential(
#         (0): Identity()
#         (1): Tanhshrink()
#       )
#       (2): Sequential(
#         (0): Linear(in_features=27, out_features=12, bias=True)
#         (1): Threshold(threshold=1.5569498237914905, value=0.5695662490823001)
#       )
#     )
#   )
#   (post_branch_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=236, out_features=10, bias=True)
#       (1): PReLU(num_parameters=1)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=10, out_features=25, bias=True)
#       (1): PReLU(num_parameters=1)
#     )
#   )
#   (final_layer): Linear(in_features=25, out_features=10, bias=True)
# )
# =====================================
# Test accuracies
# =====================================
# Model with best validation accuracy:
#
# Test set: Average loss: 4.4618, Accuracy (at final epoch): 7346/10000 (73%)
#
# Model at the end of training:
#
# Test set: Average loss: 8.2946, Accuracy (at final epoch): 6812/10000 (68%)
#
# Saving the best chromosome in the root directory (My Drive) ...
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
